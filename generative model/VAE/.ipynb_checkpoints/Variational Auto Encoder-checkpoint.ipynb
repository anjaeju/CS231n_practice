# %% [markdown]
# ## OBEJECTIVES
# - understanding the concept of VAE
#     - AE
#     - VAE
#
#
# - understanding the objective function of VAE, Evidence Lower Bound (ELBO)
#     - ELBO: KL  Divergence, Bayes Rule, Montecarlo Approximation

# %% [markdown]
# ### 한줄
# - 주어진 샘플 X로 부터 실제 latent space인 Z를 알 수 없으니까! -> p(Z|X)
# - 어떠한 샘플 q(Z)를 p(Z|X)의 가깝게 근사하자.

# %% [markdown]
# #### Auto Encoder (AE)
#
# - It consists of two parts, Encoder and Decoder.
#
# - Encoder extracts specific information about features and compress it as a format of latent variables.
#
# - 디코더는 이 latent variable로 부터 다시 자기 자신을 복제.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Encoder: 정보 압축
# - Decoder: 정보 복원
# - 정보를 압축하고 특징을 추출하는 PCA와 수학적으로 유사한 의미를 지님.
# - Clean 이미지로 encoder와 decoder를 학습한 후, 노이즈가 낀 이미지를 de-noising하는 문제에 효과적

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 64 * 64 픽셀의 얼굴이미지 (4096 차원)가 AE의 입력으로 쓰인다면,
#     - Encoder를 통해 저차운의 Hidden 공간으로 압축된다.
#     - ex) 피부색, 성별, 눈, 코, 입, 귀 라는 6가지 특징으로 압축한다고 가정.
#     - 이렇게 의미있는 정보가 담긴 압축된 hidden 차원의 전체 공간을 Latent Space.
#     - Latent space의 피부색, 성별, 눈, 코 등 6가지 특징을 Latent variables 라고 한다.
#
#
#
# - Decoder 과정은 다시 latent variables를 갖고 새로운 얼굴 이미지를 생성한다.

# %% [markdown]
# - AE 모델을 기반으로 데이터를 생성하는 모델을 만들자
#
# - Latent Space에는 사람의 얼굴에 대한 특징들을 벡터로 표현해 두었으니까, 이 벡터 공간의 값들을 조정하면 새로운 얼굴을 만들어 낼 수 있을 것이다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -> Latent Space에는 입력 데이터들에 대한 어떤 특징 정보를 함축하고 있다.
# -> 이 점에서 VAE가 주목을 받는다.

# %% [markdown]
# #### Variational Auto Encoder (VAE)
#
# ![image.png](attachment:image.png)
#
# - IDAE: 갖고 있는 이미지 데이터(고차원)들의 분포를 알고 있다면, 이 분포 내에서 샘플링을 통해 새로운 데이터 X를 추정해낼 수 있을 것이다.
#
# - 따라서 AE의 Latent Space가 어느 정규분포를 따른다면, 이 분포는 평균(mu)과 표준편차(sigma)만 구해서 분포를 표현할 수 있다.
#
# - Encoder의 출력이 mu와 sigma가 된다면, 정규분포 N에서 샘플링을 통해 잠재 변수 Z를 생성할 수 있다.
#
# - 생성된 잠재변수 z는 다시 decoder를 통해 입력된 샘플 x의 분포로 맵핑되어 대응하는 새로운 데이터를 추정할 수 있다.
#
#
#
# - 그러나, Sampling을 하게 되면 Random성을 띈다.
#     - 이를 위해 Reparametrization 트릭을 사용.
#     - N(mu, sigma) + e ... e~N(0, 1)
#     - e를 출력에 더해주는 형태를 취해 z 값에 encoder가 미치는 영향 관계를 찾을 수 있다.
#     - 즉, 미분이 가능한 모델로 표현

# %% [markdown]
# #### VAE의 목적함수
#
# - 사전지식 1. KL DIVERGENCE
#     - 두 확률 분포의 다름의 정도
#     ![image.png](attachment:image.png)
#
# - 특징!
#     - 항상 0 이상의 값을 지님
#         D_kl(P || Q) >= 0
#
#     - 두 분포가 같을 때 값이 0, 다를 수록 값이 커짐
#     - 계산 순서가 바꾸면 값이 변할 수 있음
#
#     - 두 분포가 Gaussian 분포(정규분포)를 따를 때, 간략화 가능
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 사전지식 2. 베이지안 정리
#
# - P(H|E) = {P(H) * P(E|H)} / P(E)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 사전지식 3. Monte Carlo Approximation
#
# ![image.png](attachment:image.png)
#
#
# - 위 식은 "확률 밀도 함수 p(x)를 따르는 x에 대한 f(x)의 기대값은 p(x)를 따르는 샘플들로 근사 가능"

# %% [markdown]
# - ELBO: Evidence Lower Bound
#
# ![image.png](attachment:image.png)
#
# - step 1: 주어진 샘플 X의 확률 분포를 잘 표현해보자.
#     - P(X)는 베이즈 정리에 의해 치환가능.
#     - 이때, latent variable z의 분포를 이용
#
#
#
# - step 2: 그리고 확률 P(X)는 잠재변수 z의 확률 밀도함수의 성질을 통해 Step2와 같이 나타낼 수 있습니다. P(x)의 식에 다시 자기 자신을 포함하는 재귀 형태로 식이 표현됩니다.

# %% [markdown]
# - step 1의 식을 step2의 식에 대입.
# ![image.png](attachment:image.png)
#
# - 노란색: Monte carlo approximation에 의해 기대값으로 근사하여 표현
#
# - 초록색 밑줄: term을 더하고 빼서 식의 등식이 유지될 수 있게 표현
#     - 이렇게 되면 앞서 본 KL Divergence의 식이 두개 생겨난다
#
#
# - 파란색: 잠재변수 z가 우리가 알고 있는 확률 분포(정규분포)를 따르기 때문에 KLD의 계산이 쉽다.
#
#
# - 빨간색: 이는 실제 샘플 X의 복잡한 분포인데, 실제로 알고있지 못하기 때문에 계산 불가.
#     - 다만, KLD는 항상 0 이상의 값을 갖는다는 특성이 있다.
#     - 따라서, 빨간색 부분을 제외한 나머지 부분은 항상 본 식보다 작거나 같다.

# %% [markdown]
# - step 4: ELBO의 구현
#
# ![image.png](attachment:image.png)
#
# - 따라서 logP(x_i)가 최대가 되는 매개변수를 탐색하자: x_i의 분포를 가장 잘 표현하자
#
# - 두 KLD가 모두 정규 분포를 따르기 때문에 위에서 봤듯 간략히 표현이 가능.
#
# - q(z|x_i)는 주어진 샘플 x_i에 대해 Encoder를 통과해 얻어진 mu와 sigma를 따르는 정규분포가 될 것
#
# - P(z)는 z~N(0, 1)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 샘플 x가 주어졌을 때, z가 encoder의 결과로 얻어진 분포를 따르고
#     - 다시 z로 부터 샘플 x가 생성될 확률의 기대값
#
#
# - 결국 입력 데이터가 encoder를 통해 정규분포를 따르는 어떤 공간에 표현되고, 이로부터 다시 decoder를 통과했을 때 x가 되게끔 하는 것을 목적으로 한다.
#     - 그렇기에 이 Term은 Reconstruction Error를 의미합니다.

# %% [markdown]
# #### Reconstruction Error
#
# - Reconstruction Error: 정보를 압축하거나 샘플 space의 subspace에 데이터를 projection 시켰을 때 발생하는 실제 데이터와 projected된 데이터간의 차이
#
# ![image.png](attachment:image.png)
#
# - blue points와 red 포인트간의 거리차의 총합

# %% [markdown]
# #### 즉,
#
# - x가 나타날 확률을 계산하는 것은 우리가 가지고 있는 샘플들에 대한 확률 분포를 찾고자 하는 것
# - z로부터 x가 나타날 확률을 최대화 하는 것 == MLE(최우추정법)
#     - 이는 다시 Cross-Entropy로 표현됩니다.

# %% [markdown]
# #### 결과물
#
# ![image.png](attachment:image.png)
#
# - 왼쪽: 다양한 표정의 사람 얼굴 이미지를 가지고 VAE 학습
# - 오른쪽: MNIST 데이터를 가지고 VAE 학습
#
# - 모두 Latent Space 공간을 2차원의 정규분포로 표현한 것.
# - 가운데를 원점으로 정규분포가 생성되어있다고 할 때, 그 때의 위치가 z가 되고 그 z를 기반으로 다시 이미지를 생성

# %% [markdown]
# 위의 논의를 정리해보면, 우리가
# p
# (
# z
# |
# x
# )
# 를 계산하고 싶을 때
# L
# 을 최대화하는
# q
# 를 찾아서
# q
# (
# z
# )
# 를 대신 사용하면 된다는 결론이 나온다. 즉, inference 문제인
# p
# (
# z
# |
# x
# )
# 를 optimization 문제인
# arg
# max
# q
# L
# (
# q
# )
# 로 변경한 것이

# %% [markdown]
# ### Implementation
#
# - 여기서 latent variables의 수를 20개로 하는 것은
#     - 20개의 특징을 잡겠다는 것!

# %%
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image


parser = argparse.ArgumentParser(description='VAE MNIST Example')
parser.add_argument('--batch-size', type=int, default=128, metavar='N',
                    help='input batch size for training (default: 128)')
parser.add_argument('--epochs', type=int, default=10, metavar='N',
                    help='number of epochs to train (default: 10)')
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='enables CUDA training')
parser.add_argument('--seed', type=int, default=1, metavar='S',
                    help='random seed (default: 1)')
parser.add_argument('--log-interval', type=int, default=10, metavar='N',
                    help='how many batches to wait before logging training status')
args = parser.parse_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if args.cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if args.cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=args.batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
    batch_size=args.batch_size, shuffle=True, **kwargs)


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(784, 400)
        self.fc21 = nn.Linear(400, 20)
        self.fc22 = nn.Linear(400, 20)
        self.fc3 = nn.Linear(20, 400)
        self.fc4 = nn.Linear(400, 784)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


model = VAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)


# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD


def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = loss_function(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.item() / len(data)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))


def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            recon_batch, mu, logvar = model(data)
            test_loss += loss_function(recon_batch, data, mu, logvar).item()
            if i == 0:
                n = min(data.size(0), 8)
                comparison = torch.cat([data[:n],
                                      recon_batch.view(args.batch_size, 1, 28, 28)[:n]])
                save_image(comparison.cpu(),
                         'results/reconstruction_' + str(epoch) + '.png', nrow=n)

    test_loss /= len(test_loader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))

if __name__ == "__main__":
    for epoch in range(1, args.epochs + 1):
        train(epoch)
        test(epoch)
        with torch.no_grad():
            sample = torch.randn(64, 20).to(device)
            sample = model.decode(sample).cpu()
            save_image(sample.view(64, 1, 28, 28),
                       'results/sample_' + str(epoch) + '.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8e1bfa3df54f> in <module>
#       1 from __future__ import print_function
#       2 import argparse
# ----> 3 import torch
#       4 import torch.utils.data
#       5 from torch import nn, optim
#
# ModuleNotFoundError: No module named 'torch'
